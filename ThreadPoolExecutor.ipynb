# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
from pandas.io import sql
import datetime
import pandas as pd
import pandasql as ps
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
# DB connection Info

user = 'user'
pw = 'pw'
ip = 'ip'
port = 'port'
db = 'db_name'    # SQL client -> 필요한 DB 이름 확인

# %%
# DB Connect
pymysql.install_as_MySQLdb()
cnx = create_engine("mysql://{user}:{pw}@{ip}:{port}/{db}".format(user=user, pw=pw, ip=ip, port=port, db=db))

# %%
def fetch_and_save(offset, limit, retries=3):
    for attempt in range(retries):
        try:
            # SQL 쿼리 실행
            query = f"""
            SELECT uid, ref_uid, ref_count
            FROM reference
            LIMIT {limit} OFFSET {offset};
            """
            df_chunk = pd.read_sql_query(query, cnx)
            
            if not df_chunk.empty:
                # 데이터 파일에 저장
                mode = 'w' if offset == 0 else 'a'
                header = True if offset == 0 else False
                df_chunk.to_csv(f'./mid/thread_reference/reference_chunk_{offset}.txt', sep='\t', mode=mode, index=False, header=header)
                return len(df_chunk)
            else:
                # 데이터가 비어있으면 반복을 종료하도록 0을 반환
                return 0
        except Exception as e:
            print(f"Error fetching data for offset {offset}: {e}")
            if attempt == retries - 1:
                raise
            else:
                print(f"Retrying... Attempt {attempt + 2} of {retries}")

def main(limit=1000000):
    start_time = datetime.datetime.now()
    print(f"처리 시작 시간: {start_time}")

    total_records = 0
    offset = 0

    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = []
        while True:
            print(f"청크 처리 시작: Offset {offset}")
            future = executor.submit(fetch_and_save, offset, limit)
            futures.append(future)
            offset += limit  # 다음 작업을 위해 offset 업데이트

            # 각 future의 완료를 기다리고 결과 처리
            for future in as_completed(futures):
                result = future.result()
                if result == 0:
                    # 더 이상 처리할 데이터가 없으면 루프 종료
                    print("더 이상 처리할 데이터가 없습니다. 모든 데이터 처리 완료.")
                    futures.remove(future)  # 처리 완료된 future 제거
                    break
                else:
                    # 처리된 레코드 수 업데이트 및 진행 상황 출력
                    total_records += result
                    print(f"청크 처리 완료: Offset {offset - limit}, 처리된 레코드 수: {result}")
                    futures.remove(future)  # 처리 완료된 future 제거

            if result == 0:
                break

    end_time = datetime.datetime.now()
    print(f"처리 완료 시간: {end_time}, 총 처리 시간: {end_time - start_time}, 총 처리된 레코드 수: {total_records}")
    
main()
# Out:
# 처리 시작 시간: 2024-02-19 14:47:35.395070
# 청크 처리 시작: Offset 0
# 청크 처리 완료: Offset 0, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 1000000
# 청크 처리 완료: Offset 1000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 2000000
# 청크 처리 완료: Offset 2000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 3000000
# 청크 처리 완료: Offset 3000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 4000000
# 청크 처리 완료: Offset 4000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 5000000
# 청크 처리 완료: Offset 5000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 6000000
# 청크 처리 완료: Offset 6000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 7000000
# 청크 처리 완료: Offset 7000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 8000000
# 청크 처리 완료: Offset 8000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 9000000
# 청크 처리 완료: Offset 9000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 10000000
# 청크 처리 완료: Offset 10000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 11000000
# 청크 처리 완료: Offset 11000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 12000000
# 청크 처리 완료: Offset 12000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 13000000
# 청크 처리 완료: Offset 13000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 14000000
# 청크 처리 완료: Offset 14000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 15000000
# 청크 처리 완료: Offset 15000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 16000000
# 청크 처리 완료: Offset 16000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 17000000
# 청크 처리 완료: Offset 17000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 18000000
# 청크 처리 완료: Offset 18000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 19000000
# 청크 처리 완료: Offset 19000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 20000000
# 청크 처리 완료: Offset 20000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 21000000
# 청크 처리 완료: Offset 21000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 22000000
# 청크 처리 완료: Offset 22000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 23000000
# 청크 처리 완료: Offset 23000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 24000000
# 청크 처리 완료: Offset 24000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 25000000
# 청크 처리 완료: Offset 25000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 26000000
# 청크 처리 완료: Offset 26000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 27000000
# 청크 처리 완료: Offset 27000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 28000000
# 청크 처리 완료: Offset 28000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 29000000
# 청크 처리 완료: Offset 29000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 30000000
# 청크 처리 완료: Offset 30000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 31000000
# 청크 처리 완료: Offset 31000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 32000000
# 청크 처리 완료: Offset 32000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 33000000
# 청크 처리 완료: Offset 33000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 34000000
# 청크 처리 완료: Offset 34000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 35000000
# 청크 처리 완료: Offset 35000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 36000000
# 청크 처리 완료: Offset 36000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 37000000
# 청크 처리 완료: Offset 37000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 38000000
# 청크 처리 완료: Offset 38000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 39000000
# 청크 처리 완료: Offset 39000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 40000000
# 청크 처리 완료: Offset 40000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 41000000
# 청크 처리 완료: Offset 41000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 42000000
# 청크 처리 완료: Offset 42000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 43000000
# 청크 처리 완료: Offset 43000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 44000000
# 청크 처리 완료: Offset 44000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 45000000
# 청크 처리 완료: Offset 45000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 46000000
# 청크 처리 완료: Offset 46000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 47000000
# 청크 처리 완료: Offset 47000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 48000000
# 청크 처리 완료: Offset 48000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 49000000
# 청크 처리 완료: Offset 49000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 50000000
# 청크 처리 완료: Offset 50000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 51000000
# 청크 처리 완료: Offset 51000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 52000000
# 청크 처리 완료: Offset 52000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 53000000
# 청크 처리 완료: Offset 53000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 54000000
# 청크 처리 완료: Offset 54000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 55000000
# 청크 처리 완료: Offset 55000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 56000000
# 청크 처리 완료: Offset 56000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 57000000
# 청크 처리 완료: Offset 57000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 58000000
# 청크 처리 완료: Offset 58000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 59000000
# 청크 처리 완료: Offset 59000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 60000000
# 청크 처리 완료: Offset 60000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 61000000
# 청크 처리 완료: Offset 61000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 62000000
# 청크 처리 완료: Offset 62000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 63000000
# 청크 처리 완료: Offset 63000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 64000000
# 청크 처리 완료: Offset 64000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 65000000
# 청크 처리 완료: Offset 65000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 66000000
# 청크 처리 완료: Offset 66000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 67000000
# 청크 처리 완료: Offset 67000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 68000000
# 청크 처리 완료: Offset 68000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 69000000
# 청크 처리 완료: Offset 69000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 70000000
# 청크 처리 완료: Offset 70000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 71000000
# 청크 처리 완료: Offset 71000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 72000000
# 청크 처리 완료: Offset 72000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 73000000
# 청크 처리 완료: Offset 73000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 74000000
# 청크 처리 완료: Offset 74000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 75000000
# 청크 처리 완료: Offset 75000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 76000000
# 청크 처리 완료: Offset 76000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 77000000
# 청크 처리 완료: Offset 77000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 78000000
# 청크 처리 완료: Offset 78000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 79000000
# 청크 처리 완료: Offset 79000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 80000000
# 청크 처리 완료: Offset 80000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 81000000
# 청크 처리 완료: Offset 81000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 82000000
# 청크 처리 완료: Offset 82000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 83000000
# 청크 처리 완료: Offset 83000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 84000000
# 청크 처리 완료: Offset 84000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 85000000
# 청크 처리 완료: Offset 85000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 86000000
# 청크 처리 완료: Offset 86000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 87000000
# 청크 처리 완료: Offset 87000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 88000000
# 청크 처리 완료: Offset 88000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 89000000
# 청크 처리 완료: Offset 89000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 90000000
# 청크 처리 완료: Offset 90000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 91000000
# 청크 처리 완료: Offset 91000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 92000000
# 청크 처리 완료: Offset 92000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 93000000
# 청크 처리 완료: Offset 93000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 94000000
# 청크 처리 완료: Offset 94000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 95000000
# 청크 처리 완료: Offset 95000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 96000000
# 청크 처리 완료: Offset 96000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 97000000
# 청크 처리 완료: Offset 97000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 98000000
# 청크 처리 완료: Offset 98000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 99000000
# 청크 처리 완료: Offset 99000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 100000000
# 청크 처리 완료: Offset 100000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 101000000
# 청크 처리 완료: Offset 101000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 102000000
# 청크 처리 완료: Offset 102000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 103000000
# 청크 처리 완료: Offset 103000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 104000000
# 청크 처리 완료: Offset 104000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 105000000
# 청크 처리 완료: Offset 105000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 106000000
# 청크 처리 완료: Offset 106000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 107000000
# 청크 처리 완료: Offset 107000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 108000000
# 청크 처리 완료: Offset 108000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 109000000
# 청크 처리 완료: Offset 109000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 110000000
# 청크 처리 완료: Offset 110000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 111000000
# 청크 처리 완료: Offset 111000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 112000000
# 청크 처리 완료: Offset 112000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 113000000
# 청크 처리 완료: Offset 113000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 114000000
# 청크 처리 완료: Offset 114000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 115000000
# 청크 처리 완료: Offset 115000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 116000000
# 청크 처리 완료: Offset 116000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 117000000
# 청크 처리 완료: Offset 117000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 118000000
# 청크 처리 완료: Offset 118000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 119000000
# 청크 처리 완료: Offset 119000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 120000000
# 청크 처리 완료: Offset 120000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 121000000
# 청크 처리 완료: Offset 121000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 122000000
# 청크 처리 완료: Offset 122000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 123000000
# 청크 처리 완료: Offset 123000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 124000000
# 청크 처리 완료: Offset 124000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 125000000
# 청크 처리 완료: Offset 125000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 126000000
# 청크 처리 완료: Offset 126000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 127000000
# 청크 처리 완료: Offset 127000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 128000000
# 청크 처리 완료: Offset 128000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 129000000
# 청크 처리 완료: Offset 129000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 130000000
# 청크 처리 완료: Offset 130000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 131000000
# 청크 처리 완료: Offset 131000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 132000000
# 청크 처리 완료: Offset 132000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 133000000
# 청크 처리 완료: Offset 133000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 134000000
# 청크 처리 완료: Offset 134000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 135000000
# 청크 처리 완료: Offset 135000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 136000000
# 청크 처리 완료: Offset 136000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 137000000
# 청크 처리 완료: Offset 137000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 138000000
# 청크 처리 완료: Offset 138000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 139000000
# 청크 처리 완료: Offset 139000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 140000000
# 청크 처리 완료: Offset 140000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 141000000
# 청크 처리 완료: Offset 141000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 142000000
# 청크 처리 완료: Offset 142000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 143000000
# 청크 처리 완료: Offset 143000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 144000000
# 청크 처리 완료: Offset 144000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 145000000
# 청크 처리 완료: Offset 145000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 146000000
# 청크 처리 완료: Offset 146000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 147000000
# 청크 처리 완료: Offset 147000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 148000000
# 청크 처리 완료: Offset 148000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 149000000
# 청크 처리 완료: Offset 149000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 150000000
# 청크 처리 완료: Offset 150000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 151000000
# 청크 처리 완료: Offset 151000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 152000000
# 청크 처리 완료: Offset 152000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 153000000
# 청크 처리 완료: Offset 153000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 154000000
# 청크 처리 완료: Offset 154000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 155000000
# 청크 처리 완료: Offset 155000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 156000000
# 청크 처리 완료: Offset 156000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 157000000
# 청크 처리 완료: Offset 157000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 158000000
# 청크 처리 완료: Offset 158000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 159000000
# 청크 처리 완료: Offset 159000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 160000000
# 청크 처리 완료: Offset 160000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 161000000
# 청크 처리 완료: Offset 161000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 162000000
# 청크 처리 완료: Offset 162000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 163000000
# 청크 처리 완료: Offset 163000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 164000000
# 청크 처리 완료: Offset 164000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 165000000
# 청크 처리 완료: Offset 165000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 166000000
# 청크 처리 완료: Offset 166000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 167000000
# 청크 처리 완료: Offset 167000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 168000000
# 청크 처리 완료: Offset 168000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 169000000
# 청크 처리 완료: Offset 169000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 170000000
# 청크 처리 완료: Offset 170000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 171000000
# 청크 처리 완료: Offset 171000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 172000000
# 청크 처리 완료: Offset 172000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 173000000
# 청크 처리 완료: Offset 173000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 174000000
# 청크 처리 완료: Offset 174000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 175000000
# 청크 처리 완료: Offset 175000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 176000000
# 청크 처리 완료: Offset 176000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 177000000
# 청크 처리 완료: Offset 177000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 178000000
# 청크 처리 완료: Offset 178000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 179000000
# 청크 처리 완료: Offset 179000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 180000000
# 청크 처리 완료: Offset 180000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 181000000
# 청크 처리 완료: Offset 181000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 182000000
# 청크 처리 완료: Offset 182000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 183000000
# 청크 처리 완료: Offset 183000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 184000000
# 청크 처리 완료: Offset 184000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 185000000
# 청크 처리 완료: Offset 185000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 186000000
# 청크 처리 완료: Offset 186000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 187000000
# 청크 처리 완료: Offset 187000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 188000000
# 청크 처리 완료: Offset 188000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 189000000
# 청크 처리 완료: Offset 189000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 190000000
# 청크 처리 완료: Offset 190000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 191000000
# 청크 처리 완료: Offset 191000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 192000000
# 청크 처리 완료: Offset 192000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 193000000
# 청크 처리 완료: Offset 193000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 194000000
# 청크 처리 완료: Offset 194000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 195000000
# 청크 처리 완료: Offset 195000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 196000000
# 청크 처리 완료: Offset 196000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 197000000
# 청크 처리 완료: Offset 197000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 198000000
# 청크 처리 완료: Offset 198000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 199000000
# 청크 처리 완료: Offset 199000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 200000000
# 청크 처리 완료: Offset 200000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 201000000
# 청크 처리 완료: Offset 201000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 202000000
# 청크 처리 완료: Offset 202000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 203000000
# 청크 처리 완료: Offset 203000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 204000000
# 청크 처리 완료: Offset 204000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 205000000
# 청크 처리 완료: Offset 205000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 206000000
# 청크 처리 완료: Offset 206000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 207000000
# 청크 처리 완료: Offset 207000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 208000000
# 청크 처리 완료: Offset 208000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 209000000
# 청크 처리 완료: Offset 209000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 210000000
# 청크 처리 완료: Offset 210000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 211000000
# 청크 처리 완료: Offset 211000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 212000000
# 청크 처리 완료: Offset 212000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 213000000
# 청크 처리 완료: Offset 213000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 214000000
# 청크 처리 완료: Offset 214000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 215000000
# 청크 처리 완료: Offset 215000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 216000000
# 청크 처리 완료: Offset 216000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 217000000
# 청크 처리 완료: Offset 217000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 218000000
# 청크 처리 완료: Offset 218000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 219000000
# 청크 처리 완료: Offset 219000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 220000000
# 청크 처리 완료: Offset 220000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 221000000
# 청크 처리 완료: Offset 221000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 222000000
# 청크 처리 완료: Offset 222000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 223000000
# 청크 처리 완료: Offset 223000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 224000000
# 청크 처리 완료: Offset 224000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 225000000
# 청크 처리 완료: Offset 225000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 226000000
# 청크 처리 완료: Offset 226000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 227000000
# 청크 처리 완료: Offset 227000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 228000000
# 청크 처리 완료: Offset 228000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 229000000
# 청크 처리 완료: Offset 229000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 230000000
# 청크 처리 완료: Offset 230000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 231000000
# 청크 처리 완료: Offset 231000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 232000000
# 청크 처리 완료: Offset 232000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 233000000
# 청크 처리 완료: Offset 233000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 234000000
# 청크 처리 완료: Offset 234000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 235000000
# 청크 처리 완료: Offset 235000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 236000000
# 청크 처리 완료: Offset 236000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 237000000
# 청크 처리 완료: Offset 237000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 238000000
# 청크 처리 완료: Offset 238000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 239000000
# 청크 처리 완료: Offset 239000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 240000000
# 청크 처리 완료: Offset 240000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 241000000
# 청크 처리 완료: Offset 241000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 242000000
# 청크 처리 완료: Offset 242000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 243000000
# 청크 처리 완료: Offset 243000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 244000000
# 청크 처리 완료: Offset 244000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 245000000
# 청크 처리 완료: Offset 245000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 246000000
# 청크 처리 완료: Offset 246000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 247000000
# 청크 처리 완료: Offset 247000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 248000000
# 청크 처리 완료: Offset 248000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 249000000
# 청크 처리 완료: Offset 249000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 250000000
# 청크 처리 완료: Offset 250000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 251000000
# 청크 처리 완료: Offset 251000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 252000000
# 청크 처리 완료: Offset 252000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 253000000
# 청크 처리 완료: Offset 253000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 254000000
# 청크 처리 완료: Offset 254000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 255000000
# 청크 처리 완료: Offset 255000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 256000000
# 청크 처리 완료: Offset 256000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 257000000
# 청크 처리 완료: Offset 257000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 258000000
# 청크 처리 완료: Offset 258000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 259000000
# 청크 처리 완료: Offset 259000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 260000000
# 청크 처리 완료: Offset 260000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 261000000
# 청크 처리 완료: Offset 261000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 262000000
# 청크 처리 완료: Offset 262000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 263000000
# 청크 처리 완료: Offset 263000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 264000000
# 청크 처리 완료: Offset 264000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 265000000
# 청크 처리 완료: Offset 265000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 266000000
# 청크 처리 완료: Offset 266000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 267000000
# 청크 처리 완료: Offset 267000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 268000000
# 청크 처리 완료: Offset 268000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 269000000
# 청크 처리 완료: Offset 269000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 270000000
# 청크 처리 완료: Offset 270000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 271000000
# 청크 처리 완료: Offset 271000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 272000000
# 청크 처리 완료: Offset 272000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 273000000
# 청크 처리 완료: Offset 273000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 274000000
# 청크 처리 완료: Offset 274000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 275000000
# 청크 처리 완료: Offset 275000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 276000000
# 청크 처리 완료: Offset 276000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 277000000
# 청크 처리 완료: Offset 277000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 278000000
# 청크 처리 완료: Offset 278000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 279000000
# 청크 처리 완료: Offset 279000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 280000000
# 청크 처리 완료: Offset 280000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 281000000
# 청크 처리 완료: Offset 281000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 282000000
# 청크 처리 완료: Offset 282000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 283000000
# 청크 처리 완료: Offset 283000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 284000000
# 청크 처리 완료: Offset 284000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 285000000
# 청크 처리 완료: Offset 285000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 286000000
# 청크 처리 완료: Offset 286000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 287000000
# 청크 처리 완료: Offset 287000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 288000000
# 청크 처리 완료: Offset 288000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 289000000
# 청크 처리 완료: Offset 289000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 290000000
# 청크 처리 완료: Offset 290000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 291000000
# 청크 처리 완료: Offset 291000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 292000000
# 청크 처리 완료: Offset 292000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 293000000
# 청크 처리 완료: Offset 293000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 294000000
# 청크 처리 완료: Offset 294000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 295000000
# 청크 처리 완료: Offset 295000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 296000000
# 청크 처리 완료: Offset 296000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 297000000
# 청크 처리 완료: Offset 297000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 298000000
# 청크 처리 완료: Offset 298000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 299000000
# 청크 처리 완료: Offset 299000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 300000000
# 청크 처리 완료: Offset 300000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 301000000
# 청크 처리 완료: Offset 301000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 302000000
# 청크 처리 완료: Offset 302000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 303000000
# 청크 처리 완료: Offset 303000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 304000000
# 청크 처리 완료: Offset 304000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 305000000
# 청크 처리 완료: Offset 305000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 306000000
# 청크 처리 완료: Offset 306000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 307000000
# 청크 처리 완료: Offset 307000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 308000000
# 청크 처리 완료: Offset 308000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 309000000
# 청크 처리 완료: Offset 309000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 310000000
# 청크 처리 완료: Offset 310000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 311000000
# 청크 처리 완료: Offset 311000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 312000000
# 청크 처리 완료: Offset 312000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 313000000
# 청크 처리 완료: Offset 313000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 314000000
# 청크 처리 완료: Offset 314000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 315000000
# 청크 처리 완료: Offset 315000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 316000000
# 청크 처리 완료: Offset 316000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 317000000
# 청크 처리 완료: Offset 317000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 318000000
# 청크 처리 완료: Offset 318000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 319000000
# 청크 처리 완료: Offset 319000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 320000000
# 청크 처리 완료: Offset 320000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 321000000
# 청크 처리 완료: Offset 321000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 322000000
# 청크 처리 완료: Offset 322000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 323000000
# 청크 처리 완료: Offset 323000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 324000000
# 청크 처리 완료: Offset 324000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 325000000
# 청크 처리 완료: Offset 325000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 326000000
# 청크 처리 완료: Offset 326000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 327000000
# 청크 처리 완료: Offset 327000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 328000000
# 청크 처리 완료: Offset 328000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 329000000
# 청크 처리 완료: Offset 329000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 330000000
# 청크 처리 완료: Offset 330000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 331000000
# 청크 처리 완료: Offset 331000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 332000000
# 청크 처리 완료: Offset 332000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 333000000
# 청크 처리 완료: Offset 333000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 334000000
# 청크 처리 완료: Offset 334000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 335000000
# 청크 처리 완료: Offset 335000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 336000000
# 청크 처리 완료: Offset 336000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 337000000
# 청크 처리 완료: Offset 337000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 338000000
# 청크 처리 완료: Offset 338000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 339000000
# 청크 처리 완료: Offset 339000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 340000000
# 청크 처리 완료: Offset 340000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 341000000
# 청크 처리 완료: Offset 341000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 342000000
# 청크 처리 완료: Offset 342000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 343000000
# 청크 처리 완료: Offset 343000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 344000000
# 청크 처리 완료: Offset 344000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 345000000
# 청크 처리 완료: Offset 345000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 346000000
# 청크 처리 완료: Offset 346000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 347000000
# 청크 처리 완료: Offset 347000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 348000000
# 청크 처리 완료: Offset 348000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 349000000
# 청크 처리 완료: Offset 349000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 350000000
# 청크 처리 완료: Offset 350000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 351000000
# 청크 처리 완료: Offset 351000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 352000000
# 청크 처리 완료: Offset 352000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 353000000
# 청크 처리 완료: Offset 353000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 354000000
# 청크 처리 완료: Offset 354000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 355000000
# 청크 처리 완료: Offset 355000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 356000000
# 청크 처리 완료: Offset 356000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 357000000
# 청크 처리 완료: Offset 357000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 358000000
# 청크 처리 완료: Offset 358000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 359000000
# 청크 처리 완료: Offset 359000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 360000000
# 청크 처리 완료: Offset 360000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 361000000
# 청크 처리 완료: Offset 361000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 362000000
# 청크 처리 완료: Offset 362000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 363000000
# 청크 처리 완료: Offset 363000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 364000000
# 청크 처리 완료: Offset 364000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 365000000
# 청크 처리 완료: Offset 365000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 366000000
# 청크 처리 완료: Offset 366000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 367000000
# 청크 처리 완료: Offset 367000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 368000000
# 청크 처리 완료: Offset 368000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 369000000
# 청크 처리 완료: Offset 369000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 370000000
# 청크 처리 완료: Offset 370000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 371000000
# 청크 처리 완료: Offset 371000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 372000000
# 청크 처리 완료: Offset 372000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 373000000
# 청크 처리 완료: Offset 373000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 374000000
# 청크 처리 완료: Offset 374000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 375000000
# 청크 처리 완료: Offset 375000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 376000000
# 청크 처리 완료: Offset 376000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 377000000
# 청크 처리 완료: Offset 377000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 378000000
# 청크 처리 완료: Offset 378000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 379000000
# 청크 처리 완료: Offset 379000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 380000000
# 청크 처리 완료: Offset 380000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 381000000
# 청크 처리 완료: Offset 381000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 382000000
# 청크 처리 완료: Offset 382000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 383000000
# 청크 처리 완료: Offset 383000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 384000000
# 청크 처리 완료: Offset 384000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 385000000
# 청크 처리 완료: Offset 385000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 386000000
# 청크 처리 완료: Offset 386000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 387000000
# 청크 처리 완료: Offset 387000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 388000000
# 청크 처리 완료: Offset 388000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 389000000
# 청크 처리 완료: Offset 389000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 390000000
# 청크 처리 완료: Offset 390000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 391000000
# 청크 처리 완료: Offset 391000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 392000000
# 청크 처리 완료: Offset 392000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 393000000
# 청크 처리 완료: Offset 393000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 394000000
# 청크 처리 완료: Offset 394000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 395000000
# 청크 처리 완료: Offset 395000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 396000000
# 청크 처리 완료: Offset 396000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 397000000
# 청크 처리 완료: Offset 397000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 398000000
# 청크 처리 완료: Offset 398000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 399000000
# 청크 처리 완료: Offset 399000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 400000000
# 청크 처리 완료: Offset 400000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 401000000
# 청크 처리 완료: Offset 401000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 402000000
# 청크 처리 완료: Offset 402000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 403000000
# 청크 처리 완료: Offset 403000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 404000000
# 청크 처리 완료: Offset 404000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 405000000
# 청크 처리 완료: Offset 405000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 406000000
# 청크 처리 완료: Offset 406000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 407000000
# 청크 처리 완료: Offset 407000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 408000000
# 청크 처리 완료: Offset 408000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 409000000
# 청크 처리 완료: Offset 409000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 410000000
# 청크 처리 완료: Offset 410000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 411000000
# 청크 처리 완료: Offset 411000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 412000000
# 청크 처리 완료: Offset 412000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 413000000
# 청크 처리 완료: Offset 413000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 414000000
# 청크 처리 완료: Offset 414000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 415000000
# 청크 처리 완료: Offset 415000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 416000000
# 청크 처리 완료: Offset 416000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 417000000
# 청크 처리 완료: Offset 417000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 418000000
# 청크 처리 완료: Offset 418000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 419000000
# 청크 처리 완료: Offset 419000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 420000000
# 청크 처리 완료: Offset 420000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 421000000
# 청크 처리 완료: Offset 421000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 422000000
# 청크 처리 완료: Offset 422000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 423000000
# 청크 처리 완료: Offset 423000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 424000000
# 청크 처리 완료: Offset 424000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 425000000
# 청크 처리 완료: Offset 425000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 426000000
# 청크 처리 완료: Offset 426000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 427000000
# 청크 처리 완료: Offset 427000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 428000000
# 청크 처리 완료: Offset 428000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 429000000
# 청크 처리 완료: Offset 429000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 430000000
# 청크 처리 완료: Offset 430000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 431000000
# 청크 처리 완료: Offset 431000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 432000000
# 청크 처리 완료: Offset 432000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 433000000
# 청크 처리 완료: Offset 433000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 434000000
# 청크 처리 완료: Offset 434000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 435000000
# 청크 처리 완료: Offset 435000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 436000000
# 청크 처리 완료: Offset 436000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 437000000
# 청크 처리 완료: Offset 437000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 438000000
# 청크 처리 완료: Offset 438000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 439000000
# 청크 처리 완료: Offset 439000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 440000000
# 청크 처리 완료: Offset 440000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 441000000
# 청크 처리 완료: Offset 441000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 442000000
# 청크 처리 완료: Offset 442000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 443000000
# 청크 처리 완료: Offset 443000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 444000000
# 청크 처리 완료: Offset 444000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 445000000
# 청크 처리 완료: Offset 445000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 446000000
# 청크 처리 완료: Offset 446000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 447000000
# 청크 처리 완료: Offset 447000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 448000000
# 청크 처리 완료: Offset 448000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 449000000
# 청크 처리 완료: Offset 449000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 450000000
# 청크 처리 완료: Offset 450000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 451000000
# 청크 처리 완료: Offset 451000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 452000000
# 청크 처리 완료: Offset 452000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 453000000
# 청크 처리 완료: Offset 453000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 454000000
# 청크 처리 완료: Offset 454000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 455000000
# 청크 처리 완료: Offset 455000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 456000000
# 청크 처리 완료: Offset 456000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 457000000
# 청크 처리 완료: Offset 457000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 458000000
# 청크 처리 완료: Offset 458000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 459000000
# 청크 처리 완료: Offset 459000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 460000000
# 청크 처리 완료: Offset 460000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 461000000
# 청크 처리 완료: Offset 461000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 462000000
# 청크 처리 완료: Offset 462000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 463000000
# 청크 처리 완료: Offset 463000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 464000000
# 청크 처리 완료: Offset 464000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 465000000
# 청크 처리 완료: Offset 465000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 466000000
# 청크 처리 완료: Offset 466000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 467000000
# 청크 처리 완료: Offset 467000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 468000000
# 청크 처리 완료: Offset 468000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 469000000
# 청크 처리 완료: Offset 469000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 470000000
# 청크 처리 완료: Offset 470000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 471000000
# 청크 처리 완료: Offset 471000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 472000000
# 청크 처리 완료: Offset 472000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 473000000
# 청크 처리 완료: Offset 473000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 474000000
# 청크 처리 완료: Offset 474000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 475000000
# 청크 처리 완료: Offset 475000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 476000000
# 청크 처리 완료: Offset 476000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 477000000
# 청크 처리 완료: Offset 477000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 478000000
# 청크 처리 완료: Offset 478000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 479000000
# 청크 처리 완료: Offset 479000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 480000000
# 청크 처리 완료: Offset 480000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 481000000
# 청크 처리 완료: Offset 481000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 482000000
# 청크 처리 완료: Offset 482000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 483000000
# 청크 처리 완료: Offset 483000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 484000000
# 청크 처리 완료: Offset 484000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 485000000
# 청크 처리 완료: Offset 485000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 486000000
# 청크 처리 완료: Offset 486000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 487000000
# 청크 처리 완료: Offset 487000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 488000000
# 청크 처리 완료: Offset 488000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 489000000
# 청크 처리 완료: Offset 489000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 490000000
# 청크 처리 완료: Offset 490000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 491000000
# 청크 처리 완료: Offset 491000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 492000000
# 청크 처리 완료: Offset 492000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 493000000
# 청크 처리 완료: Offset 493000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 494000000
# 청크 처리 완료: Offset 494000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 495000000
# 청크 처리 완료: Offset 495000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 496000000
# 청크 처리 완료: Offset 496000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 497000000
# 청크 처리 완료: Offset 497000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 498000000
# 청크 처리 완료: Offset 498000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 499000000
# 청크 처리 완료: Offset 499000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 500000000
# 청크 처리 완료: Offset 500000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 501000000
# 청크 처리 완료: Offset 501000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 502000000
# 청크 처리 완료: Offset 502000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 503000000
# 청크 처리 완료: Offset 503000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 504000000
# 청크 처리 완료: Offset 504000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 505000000
# 청크 처리 완료: Offset 505000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 506000000
# 청크 처리 완료: Offset 506000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 507000000
# 청크 처리 완료: Offset 507000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 508000000
# 청크 처리 완료: Offset 508000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 509000000
# 청크 처리 완료: Offset 509000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 510000000
# 청크 처리 완료: Offset 510000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 511000000
# 청크 처리 완료: Offset 511000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 512000000
# 청크 처리 완료: Offset 512000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 513000000
# 청크 처리 완료: Offset 513000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 514000000
# 청크 처리 완료: Offset 514000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 515000000
# 청크 처리 완료: Offset 515000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 516000000
# 청크 처리 완료: Offset 516000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 517000000
# 청크 처리 완료: Offset 517000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 518000000
# 청크 처리 완료: Offset 518000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 519000000
# 청크 처리 완료: Offset 519000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 520000000
# 청크 처리 완료: Offset 520000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 521000000
# 청크 처리 완료: Offset 521000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 522000000
# 청크 처리 완료: Offset 522000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 523000000
# 청크 처리 완료: Offset 523000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 524000000
# 청크 처리 완료: Offset 524000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 525000000
# 청크 처리 완료: Offset 525000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 526000000
# 청크 처리 완료: Offset 526000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 527000000
# 청크 처리 완료: Offset 527000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 528000000
# 청크 처리 완료: Offset 528000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 529000000
# 청크 처리 완료: Offset 529000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 530000000
# 청크 처리 완료: Offset 530000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 531000000
# 청크 처리 완료: Offset 531000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 532000000
# 청크 처리 완료: Offset 532000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 533000000
# 청크 처리 완료: Offset 533000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 534000000
# 청크 처리 완료: Offset 534000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 535000000
# 청크 처리 완료: Offset 535000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 536000000
# 청크 처리 완료: Offset 536000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 537000000
# 청크 처리 완료: Offset 537000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 538000000
# 청크 처리 완료: Offset 538000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 539000000
# 청크 처리 완료: Offset 539000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 540000000
# 청크 처리 완료: Offset 540000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 541000000
# 청크 처리 완료: Offset 541000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 542000000
# 청크 처리 완료: Offset 542000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 543000000
# 청크 처리 완료: Offset 543000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 544000000
# 청크 처리 완료: Offset 544000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 545000000
# 청크 처리 완료: Offset 545000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 546000000
# 청크 처리 완료: Offset 546000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 547000000
# 청크 처리 완료: Offset 547000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 548000000
# 청크 처리 완료: Offset 548000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 549000000
# 청크 처리 완료: Offset 549000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 550000000
# 청크 처리 완료: Offset 550000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 551000000
# 청크 처리 완료: Offset 551000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 552000000
# 청크 처리 완료: Offset 552000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 553000000
# 청크 처리 완료: Offset 553000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 554000000
# 청크 처리 완료: Offset 554000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 555000000
# 청크 처리 완료: Offset 555000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 556000000
# 청크 처리 완료: Offset 556000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 557000000
# 청크 처리 완료: Offset 557000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 558000000
# 청크 처리 완료: Offset 558000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 559000000
# 청크 처리 완료: Offset 559000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 560000000
# 청크 처리 완료: Offset 560000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 561000000
# 청크 처리 완료: Offset 561000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 562000000
# 청크 처리 완료: Offset 562000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 563000000
# 청크 처리 완료: Offset 563000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 564000000
# 청크 처리 완료: Offset 564000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 565000000
# 청크 처리 완료: Offset 565000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 566000000
# 청크 처리 완료: Offset 566000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 567000000
# 청크 처리 완료: Offset 567000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 568000000
# 청크 처리 완료: Offset 568000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 569000000
# 청크 처리 완료: Offset 569000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 570000000
# 청크 처리 완료: Offset 570000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 571000000
# 청크 처리 완료: Offset 571000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 572000000
# 청크 처리 완료: Offset 572000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 573000000
# 청크 처리 완료: Offset 573000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 574000000
# 청크 처리 완료: Offset 574000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 575000000
# 청크 처리 완료: Offset 575000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 576000000
# 청크 처리 완료: Offset 576000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 577000000
# 청크 처리 완료: Offset 577000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 578000000
# 청크 처리 완료: Offset 578000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 579000000
# 청크 처리 완료: Offset 579000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 580000000
# 청크 처리 완료: Offset 580000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 581000000
# 청크 처리 완료: Offset 581000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 582000000
# 청크 처리 완료: Offset 582000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 583000000
# 청크 처리 완료: Offset 583000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 584000000
# 청크 처리 완료: Offset 584000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 585000000
# 청크 처리 완료: Offset 585000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 586000000
# 청크 처리 완료: Offset 586000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 587000000
# 청크 처리 완료: Offset 587000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 588000000
# 청크 처리 완료: Offset 588000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 589000000
# 청크 처리 완료: Offset 589000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 590000000
# 청크 처리 완료: Offset 590000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 591000000
# 청크 처리 완료: Offset 591000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 592000000
# 청크 처리 완료: Offset 592000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 593000000
# 청크 처리 완료: Offset 593000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 594000000
# 청크 처리 완료: Offset 594000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 595000000
# 청크 처리 완료: Offset 595000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 596000000
# 청크 처리 완료: Offset 596000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 597000000
# 청크 처리 완료: Offset 597000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 598000000
# 청크 처리 완료: Offset 598000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 599000000
# 청크 처리 완료: Offset 599000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 600000000
# 청크 처리 완료: Offset 600000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 601000000
# 청크 처리 완료: Offset 601000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 602000000
# 청크 처리 완료: Offset 602000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 603000000
# 청크 처리 완료: Offset 603000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 604000000
# 청크 처리 완료: Offset 604000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 605000000
# 청크 처리 완료: Offset 605000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 606000000
# 청크 처리 완료: Offset 606000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 607000000
# 청크 처리 완료: Offset 607000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 608000000
# 청크 처리 완료: Offset 608000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 609000000
# 청크 처리 완료: Offset 609000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 610000000
# 청크 처리 완료: Offset 610000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 611000000
# 청크 처리 완료: Offset 611000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 612000000
# 청크 처리 완료: Offset 612000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 613000000
# 청크 처리 완료: Offset 613000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 614000000
# 청크 처리 완료: Offset 614000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 615000000
# 청크 처리 완료: Offset 615000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 616000000
# 청크 처리 완료: Offset 616000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 617000000
# 청크 처리 완료: Offset 617000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 618000000
# 청크 처리 완료: Offset 618000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 619000000
# 청크 처리 완료: Offset 619000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 620000000
# 청크 처리 완료: Offset 620000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 621000000
# 청크 처리 완료: Offset 621000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 622000000
# 청크 처리 완료: Offset 622000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 623000000
# 청크 처리 완료: Offset 623000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 624000000
# 청크 처리 완료: Offset 624000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 625000000
# 청크 처리 완료: Offset 625000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 626000000
# 청크 처리 완료: Offset 626000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 627000000
# 청크 처리 완료: Offset 627000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 628000000
# 청크 처리 완료: Offset 628000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 629000000
# 청크 처리 완료: Offset 629000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 630000000
# 청크 처리 완료: Offset 630000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 631000000
# 청크 처리 완료: Offset 631000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 632000000
# 청크 처리 완료: Offset 632000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 633000000
# 청크 처리 완료: Offset 633000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 634000000
# 청크 처리 완료: Offset 634000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 635000000
# 청크 처리 완료: Offset 635000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 636000000
# 청크 처리 완료: Offset 636000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 637000000
# 청크 처리 완료: Offset 637000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 638000000
# 청크 처리 완료: Offset 638000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 639000000
# 청크 처리 완료: Offset 639000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 640000000
# 청크 처리 완료: Offset 640000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 641000000
# 청크 처리 완료: Offset 641000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 642000000
# 청크 처리 완료: Offset 642000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 643000000
# 청크 처리 완료: Offset 643000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 644000000
# 청크 처리 완료: Offset 644000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 645000000
# 청크 처리 완료: Offset 645000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 646000000
# 청크 처리 완료: Offset 646000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 647000000
# 청크 처리 완료: Offset 647000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 648000000
# 청크 처리 완료: Offset 648000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 649000000
# 청크 처리 완료: Offset 649000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 650000000
# 청크 처리 완료: Offset 650000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 651000000
# 청크 처리 완료: Offset 651000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 652000000
# 청크 처리 완료: Offset 652000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 653000000
# 청크 처리 완료: Offset 653000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 654000000
# 청크 처리 완료: Offset 654000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 655000000
# 청크 처리 완료: Offset 655000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 656000000
# 청크 처리 완료: Offset 656000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 657000000
# 청크 처리 완료: Offset 657000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 658000000
# 청크 처리 완료: Offset 658000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 659000000
# 청크 처리 완료: Offset 659000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 660000000
# 청크 처리 완료: Offset 660000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 661000000
# 청크 처리 완료: Offset 661000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 662000000
# 청크 처리 완료: Offset 662000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 663000000
# 청크 처리 완료: Offset 663000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 664000000
# 청크 처리 완료: Offset 664000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 665000000
# 청크 처리 완료: Offset 665000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 666000000
# 청크 처리 완료: Offset 666000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 667000000
# 청크 처리 완료: Offset 667000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 668000000
# 청크 처리 완료: Offset 668000000, 처리된 레코드 수: 1000000
# 청크 처리 시작: Offset 669000000
